# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import us
import folium
from folium import plugins
import time
from geopy.geocoders import Nominatim

# %% [markdown]
# # Historic Data Exploration

# %% [markdown]
# ## Natural Disasters

# %%
# summary of all states (combined from map_data above)

nat_dis = pd.read_csv('./../Natural_Disaster_Data/DisasterDeclarationsSummaries.csv')
print(nat_dis.shape)
nat_dis.head(3)
# Out:
# (58771, 19)
#    disasterNumber  ihProgramDeclared  iaProgramDeclared  paProgramDeclared  \
# 0               1                  0                  1                  1
# 1               2                  0                  1                  1
# 2               3                  0                  1                  1
#
#    hmProgramDeclared state           declarationDate  fyDeclared disasterType  \
# 0                  1    GA  1953-05-02T00:00:00.000Z        1953           DR
# 1                  1    TX  1953-05-15T00:00:00.000Z        1953           DR
# 2                  1    LA  1953-05-29T00:00:00.000Z        1953           DR
#
#   incidentType                     title         incidentBeginDate  \
# 0      Tornado                   TORNADO  1953-05-02T00:00:00.000Z
# 1      Tornado  TORNADO & HEAVY RAINFALL  1953-05-15T00:00:00.000Z
# 2        Flood                     FLOOD  1953-05-29T00:00:00.000Z
#
#             incidentEndDate      disasterCloseOutDate declaredCountyArea  \
# 0  1953-05-02T00:00:00.000Z  1954-06-01T00:00:00.000Z                NaN
# 1  1953-05-15T00:00:00.000Z  1958-01-01T00:00:00.000Z                NaN
# 2  1953-05-29T00:00:00.000Z  1960-02-01T00:00:00.000Z                NaN
#
#    placeCode                              hash               lastRefresh  \
# 0        NaN  1dcb40d0664d22d39de787b706b0fa69  2019-07-26T18:08:57.368Z
# 1        NaN  61612cea5779e361b429799098974b6a  2019-07-26T18:08:57.370Z
# 2        NaN  86f3e47785cb7acc51364d4535d36101  2019-07-26T18:08:57.369Z
#
#                          id
# 0  5d1bbd8c8bdcfa6efb32fd8d
# 1  5d1bbd8c8bdcfa6efb32fd8e
# 2  5d1bbd8c8bdcfa6efb32fd8f

# %%
nat_dis.columns
# Out:
# Index(['disasterNumber', 'ihProgramDeclared', 'iaProgramDeclared',
#        'paProgramDeclared', 'hmProgramDeclared', 'state', 'declarationDate',
#        'fyDeclared', 'disasterType', 'incidentType', 'title',
#        'incidentBeginDate', 'incidentEndDate', 'disasterCloseOutDate',
#        'declaredCountyArea', 'placeCode', 'hash', 'lastRefresh', 'id'],
#       dtype='object')

# %%
nat_dis.isnull().sum().sort_values(ascending = False)
# Out:
# disasterCloseOutDate    16569
# incidentEndDate          8033
# placeCode                 235
# declaredCountyArea        235
# hash                       73
# lastRefresh                73
# id                          0
# state                       0
# ihProgramDeclared           0
# iaProgramDeclared           0
# paProgramDeclared           0
# hmProgramDeclared           0
# incidentType                0
# declarationDate             0
# fyDeclared                  0
# disasterType                0
# title                       0
# incidentBeginDate           0
# disasterNumber              0
# dtype: int64

# %%
pd.set_option('display.max_rows', 500)
pd.DataFrame(nat_dis.groupby('state')['incidentType'].value_counts())
# Out:
#                         incidentType
# state incidentType
# AK    Biological                  71
#       Severe Storm(s)             64
#       Flood                       47
#       Fire                        21
#       Freezing                    14
#       Earthquake                  13
#       Other                        4
#       Snow                         4
#       Coastal Storm                2
#       Biological                  28
#       Hurricane                   28
#       Severe Ice Storm             9
#       Snow                         9
#       Drought                      2
# WA    Flood                      255
#       Severe Storm(s)            223
#       Fire                       136
#       Biological                  79
#       Coastal Storm               39
#       Volcano                     39
#       Earthquake                  30
#       Drought                     16
#       Fishing Losses               6
#       Mud/Landslide                6
#       Severe Ice Storm             3
# WI    Severe Storm(s)            293
#       Flood                      207
#       Biological                 166
#       Hurricane                   73
#       Drought                     66
#       Tornado                     47
#       Snow                        39
# WV    Severe Storm(s)            460
#       Flood                      285
#       Snow                       148
#       Hurricane                  141
#       Biological                 110
#       Fire                        24
#       Drought                     21
#       Mud/Landslide               21
#       Chemical                     9
# WY    Biological                  48
#       Flood                       24
#       Fire                        23
#       Severe Storm(s)             21
#       Drought                      4
#       Severe Ice Storm             2
#       Tornado                      2
#       Toxic Substances             1

# %%
nat_dis['declarationDate'] = pd.to_datetime(nat_dis['declarationDate'])
nat_dis['incidentBeginDate'] = pd.to_datetime(nat_dis['incidentBeginDate'])
nat_dis['incidentEndDate'] = pd.to_datetime(nat_dis['incidentEndDate'])

# %%
nat_dis['beginMonth'] = nat_dis['incidentBeginDate'].dt.month
nat_dis['beginYear'] = nat_dis['incidentBeginDate'].dt.year
nat_dis['beginDay'] = nat_dis['incidentBeginDate'].dt.day

# %%
nat_dis['beginMonth'].value_counts()
# Out:
# 1     12483
# 8      6923
# 9      6589
# 4      5026
# 5      4616
# 3      4480
# 6      4116
# 2      3759
# 12     3755
# 10     3064
# 7      2299
# 11     1661
# Name: beginMonth, dtype: int64

# %%
nat_dis[nat_dis['beginYear'] == 2020][['incidentBeginDate', 'disasterType', 'incidentType', 'state', 'declaredCountyArea']].isnull().sum()
# Out:
# incidentBeginDate      0
# disasterType           0
# incidentType           0
# state                  0
# declaredCountyArea    21
# dtype: int64

# %%
nat_dis_2020 = nat_dis[(nat_dis['beginYear'] == 2020) & (nat_dis['incidentType'] != 'Biological')][['disasterType', 'incidentType', 'declaredCountyArea', 'state', 'beginYear', 'beginMonth', 'beginDay', 'incidentBeginDate']]
nat_dis_2020.dropna(inplace = True)

counties_2020 = []
for county in nat_dis_2020['declaredCountyArea']:
    if county.endswith('(County)'):
        counties_2020.append(county[:-9])
    else:
        counties_2020.append(county)

# %%
nat_dis_2020['declaredCountyArea'] = counties_2020

# %%
nat_dis_2020.drop(index = 57357, inplace = True)

# %%
nat_dis_2020['address'] = nat_dis_2020['declaredCountyArea'] + ' County, ' + nat_dis_2020['state']

# %%
geolocator = Nominatim(user_agent="griffin_app_1")
address_latlong = []

for address in nat_dis_2020['address']:
    location = geolocator.geocode(address)
    address_latlong.append([address, location.latitude, location.longitude])
    time.sleep(1)
    
address_latlong[:5]
# Out:
# [['Wilson County, TN', 36.1466658, -86.3119998],
#  ['Putnam County, TN', 36.1379872, -85.4553784],
#  ['Davidson County, TN', 36.189724, -86.7857862],
#  ['Beaver County, OK', 36.7621116, -100.4904955],
#  ['Milwaukee County, WI', 43.018032500000004, -87.97408733038324]]

# %%
address_latlong = pd.DataFrame(address_latlong)

# %%
address_latlong.columns = ['address', 'latitude', 'longitude']

# %%
nat_dis_2020_latlong = pd.merge(nat_dis_2020, address_latlong, on = 'address')

# %%
nat_dis_2020_latlong.head(5)
# Out:
#   disasterType incidentType declaredCountyArea state  beginYear  beginMonth  \
# 0           DR      Tornado             Wilson    TN       2020           3
# 1           DR      Tornado             Putnam    TN       2020           3
# 2           DR      Tornado           Davidson    TN       2020           3
# 3           FM         Fire             Beaver    OK       2020           3
# 4           DR        Flood          Milwaukee    WI       2020           1
#
#    beginDay         incidentBeginDate               address   latitude  \
# 0         3 2020-03-03 00:01:00+00:00     Wilson County, TN  36.146666
# 1         3 2020-03-03 00:01:00+00:00     Putnam County, TN  36.137987
# 2         3 2020-03-03 00:01:00+00:00   Davidson County, TN  36.189724
# 3         7 2020-03-07 08:00:00+00:00     Beaver County, OK  36.762112
# 4        10 2020-01-10 00:00:00+00:00  Milwaukee County, WI  43.018033
#
#     longitude
# 0  -86.312000
# 1  -85.455378
# 2  -86.785786
# 3 -100.490495
# 4  -87.974087

# %%
nat_dis_2020_latlong.state.value_counts()
# Out:
# MS    29
# SC    27
# KY    27
# WA    15
# TN    14
# WI     3
# OR     3
# OK     1
# Name: state, dtype: int64

# %%
nat_dis_2020_latlong.head()
# Out:
#   disasterType incidentType declaredCountyArea state  beginYear  beginMonth  \
# 0           DR      Tornado             Wilson    TN       2020           3
# 1           DR      Tornado             Putnam    TN       2020           3
# 2           DR      Tornado           Davidson    TN       2020           3
# 3           FM         Fire             Beaver    OK       2020           3
# 4           DR        Flood          Milwaukee    WI       2020           1
#
#    beginDay         incidentBeginDate               address   latitude  \
# 0         3 2020-03-03 00:01:00+00:00     Wilson County, TN  36.146666
# 1         3 2020-03-03 00:01:00+00:00     Putnam County, TN  36.137987
# 2         3 2020-03-03 00:01:00+00:00   Davidson County, TN  36.189724
# 3         7 2020-03-07 08:00:00+00:00     Beaver County, OK  36.762112
# 4        10 2020-01-10 00:00:00+00:00  Milwaukee County, WI  43.018033
#
#     longitude
# 0  -86.312000
# 1  -85.455378
# 2  -86.785786
# 3 -100.490495
# 4  -87.974087

# %%
nat_dis_2020_latlong.dtypes
# Out:
# disasterType                       object
# incidentType                       object
# declaredCountyArea                 object
# state                              object
# beginYear                           int64
# beginMonth                          int64
# beginDay                            int64
# incidentBeginDate     datetime64[ns, UTC]
# address                            object
# latitude                          float64
# longitude                         float64
# dtype: object

# %%
nat_dis_2020_latlong.drop(columns = ['disasterType', 'declaredCountyArea', 'beginMonth', 'beginDay', 'beginYear', 'state'], inplace = True)

# %%
nat_dis_2020_latlong.head()
# Out:
#   incidentType         incidentBeginDate               address   latitude  \
# 0      Tornado 2020-03-03 00:01:00+00:00     Wilson County, TN  36.146666
# 1      Tornado 2020-03-03 00:01:00+00:00     Putnam County, TN  36.137987
# 2      Tornado 2020-03-03 00:01:00+00:00   Davidson County, TN  36.189724
# 3         Fire 2020-03-07 08:00:00+00:00     Beaver County, OK  36.762112
# 4        Flood 2020-01-10 00:00:00+00:00  Milwaukee County, WI  43.018033
#
#     longitude
# 0  -86.312000
# 1  -85.455378
# 2  -86.785786
# 3 -100.490495
# 4  -87.974087

# %%
nat_dis_2020_latlong.to_csv('./../Mapping_Data/natdis_2020_map.csv', index = False)

# %% [markdown]
# ## COVID-19

# %%
covid = pd.read_csv('./../COVID_Data/Historic_data/CCSE/time_series_covid19_confirmed_US.csv')

# %%
print(covid.shape)
covid.head(8)
# Out:
# (3261, 117)
#           UID iso2 iso3  code3    FIPS   Admin2            Province_State  \
# 0        16.0   AS  ASM     16    60.0      NaN            American Samoa
# 1       316.0   GU  GUM    316    66.0      NaN                      Guam
# 2       580.0   MP  MNP    580    69.0      NaN  Northern Mariana Islands
# 3       630.0   PR  PRI    630    72.0      NaN               Puerto Rico
# 4       850.0   VI  VIR    850    78.0      NaN            Virgin Islands
# 5  84001001.0   US  USA    840  1001.0  Autauga                   Alabama
# 6  84001003.0   US  USA    840  1003.0  Baldwin                   Alabama
# 7  84001005.0   US  USA    840  1005.0  Barbour                   Alabama
#
#   Country_Region        Lat       Long_  ... 4/27/20  4/28/20  4/29/20  \
# 0             US -14.271000 -170.132000  ...       0        0        0
# 1             US  13.444300  144.793700  ...     141      141      141
# 2             US  15.097900  145.673900  ...      14       14       14
# 3             US  18.220800  -66.590100  ...    1389     1400     1433
# 4             US  18.335800  -64.896300  ...      57       57       57
# 5             US  32.539527  -86.644082  ...      39       40       43
# 6             US  30.727750  -87.722071  ...     168      171      174
# 7             US  31.868263  -85.387129  ...      35       37       37
#
#    4/30/20  5/1/20  5/2/20  5/3/20  5/4/20  5/5/20  5/6/20
# 0        0       0       0       0       0       0       0
# 1      145     145     145     145     145     145     149
# 2       14      14      14      14      14      14      15
# 3     1539    1575    1757    1808    1843    1924    1968
# 4       66      66      66      66      66      66      66
# 5       44      42      45      48      53      53      58
# 6      174     175     181     187     188     189     196
# 7       39      42      43      45      45      47      47
#
# [8 rows x 117 columns]

# %%
covid = covid.drop(columns = ['UID', 'iso2', 'iso3', 'code3', 'FIPS', 'Admin2', 'Combined_Key'])

# %%
covid.columns
# Out:
# Index(['Province_State', 'Country_Region', 'Lat', 'Long_', '1/22/20',
#        '1/23/20', '1/24/20', '1/25/20', '1/26/20', '1/27/20',
#        ...
#        '4/27/20', '4/28/20', '4/29/20', '4/30/20', '5/1/20', '5/2/20',
#        '5/3/20', '5/4/20', '5/5/20', '5/6/20'],
#       dtype='object', length=110)

# %%
formatted_covid = []
for i, row in covid.iterrows():
    for index, column in enumerate(covid.columns[4:], start = 4):
        formatted_covid.append([row[0], row[1], row[2], row[3], column, row[index]])

# %%
formatted_covid = pd.DataFrame(formatted_covid)

# %%
formatted_covid.head(2)
# Out:
#                 0   1       2        3        4  5
# 0  American Samoa  US -14.271 -170.132  1/22/20  0
# 1  American Samoa  US -14.271 -170.132  1/23/20  0

# %%
formatted_covid.columns = ['State', 'Country', 'Latitude', 'Longitude', 'Date', 'Cases']

# %%
formatted_covid.head(2)
# Out:
#             State Country  Latitude  Longitude     Date  Cases
# 0  American Samoa      US   -14.271   -170.132  1/22/20      0
# 1  American Samoa      US   -14.271   -170.132  1/23/20      0

# %%
formatted_covid['Date'] = pd.to_datetime(formatted_covid['Date'])

# %%
pops = pd.read_csv('../COVID_Data/Population_data/state_population_data.csv')

# %%
pops = pops[['NAME', 'POPESTIMATE2019']]

# %%
pops = pops.rename(columns={'NAME': 'State', 'POPESTIMATE2019': 'est_population'})

# %%
US_states = [str(s) for s in us.states.STATES]

# %%
pops = pops.loc[pops['State'].isin(US_states)]

# %%
pops.set_index('State', inplace=True)

# %%
formatted_covid = formatted_covid.join(pops, on='State', how='left')

# %%
formatted_covid[formatted_covid['est_population'].isnull()]['State'].value_counts()
# Out:
# District of Columbia        318
# Virgin Islands              106
# Diamond Princess            106
# Guam                        106
# American Samoa              106
# Grand Princess              106
# Northern Mariana Islands    106
# Puerto Rico                 106
# Name: State, dtype: int64

# %%
formatted_covid.dropna(inplace = True)

# %%
formatted_covid
# Out:
#           State Country   Latitude   Longitude       Date  Cases  \
# 530     Alabama      US  32.539527  -86.644082 2020-01-22      0
# 531     Alabama      US  32.539527  -86.644082 2020-01-23      0
# 532     Alabama      US  32.539527  -86.644082 2020-01-24      0
# 533     Alabama      US  32.539527  -86.644082 2020-01-25      0
# 534     Alabama      US  32.539527  -86.644082 2020-01-26      0
# ...         ...     ...        ...         ...        ...    ...
# 345661     Utah      US  41.271160 -111.914512 2020-05-02    166
# 345662     Utah      US  41.271160 -111.914512 2020-05-03    167
# 345663     Utah      US  41.271160 -111.914512 2020-05-04    167
# 345664     Utah      US  41.271160 -111.914512 2020-05-05    173
# 345665     Utah      US  41.271160 -111.914512 2020-05-06    173
#
#         est_population
# 530          4903185.0
# 531          4903185.0
# 532          4903185.0
# 533          4903185.0
# 534          4903185.0
# ...                ...
# 345661       3205958.0
# 345662       3205958.0
# 345663       3205958.0
# 345664       3205958.0
# 345665       3205958.0
#
# [344606 rows x 7 columns]

# %%
formatted_covid['case_weight'] = formatted_covid['Cases'] / formatted_covid['est_population']

# %%
formatted_covid.head()
# Out:
#        State Country   Latitude  Longitude       Date  Cases  est_population  \
# 530  Alabama      US  32.539527 -86.644082 2020-01-22      0       4903185.0
# 531  Alabama      US  32.539527 -86.644082 2020-01-23      0       4903185.0
# 532  Alabama      US  32.539527 -86.644082 2020-01-24      0       4903185.0
# 533  Alabama      US  32.539527 -86.644082 2020-01-25      0       4903185.0
# 534  Alabama      US  32.539527 -86.644082 2020-01-26      0       4903185.0
#
#      case_weight
# 530          0.0
# 531          0.0
# 532          0.0
# 533          0.0
# 534          0.0

# %%
formatted_covid.drop(columns = ['Country', 'est_population'], inplace = True)

# %%
formatted_covid.rename(columns = {'case_weight' : 'Cases_per_pop'}, inplace = True)

# %%
formatted_covid.sort_values(by = 'Cases_per_pop', ascending = False).head()
# Out:
#            State   Latitude  Longitude       Date   Cases  Cases_per_pop
# 197583  New York  40.767273 -73.971526 2020-05-06  178351       0.009168
# 197582  New York  40.767273 -73.971526 2020-05-05  176874       0.009092
# 197581  New York  40.767273 -73.971526 2020-05-04  175651       0.009029
# 197580  New York  40.767273 -73.971526 2020-05-03  174331       0.008961
# 197579  New York  40.767273 -73.971526 2020-05-02  172354       0.008860

# %%
formatted_covid.to_csv('./../Mapping_Data/historic_covid_map.csv', index = False)
